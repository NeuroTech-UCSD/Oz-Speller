# %% [markdown]
# # Import

# %%
# installations
# !pip install mne
# !pip install tensorflow
# !pip install seaborn
# !pip install sklearn

# %%
import scipy.io
from scipy.fftpack import fft

import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_theme()

from mne.filter import filter_data, notch_filter
import mne

# %%
# for training the model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Constants

# %%
recording_freq = 250  # how frequent our data streamer is getting the data, in this case, 250 Hz, in other words, we'll get 1 timepoint every 4 ms = 1000 / 250
timepoint_to_ms = 1 / recording_freq * 1000
epoch_length = 2840  # ms
ms_to_timepoint = 1 / timepoint_to_ms
epoch_start = -500  # the time stamp where the recording starts, ms
onset_idx = int(abs(epoch_start) * ms_to_timepoint) + 1 # index beyond this point corresponds to event onset
num_blocks = 10
channels = ['POz', 'PO3', 'PO4', 'PO5', 'PO6', 'Oz', 'O1', 'O2']
meta = {
  'recording_freq':recording_freq, # unit: Hz
  'timepoint_to_ms':timepoint_to_ms, # equals 4 ms/timepoint
  'ms_to_timepoint':ms_to_timepoint, # equals 0.25 timepoint/ms
  'num_channels':len(channels),
  'epoch_length': epoch_length, # unit: ms
  'epoch_length_timepoint':int(epoch_length * ms_to_timepoint), # equals 710 timepoint
  'channels':channels, # the exact same order as X
  'epoch_start': epoch_start, # unit: ms
  'onset': 0, # unit: ms
  'electrode_index': dict(dry=1, wet=2),
  'blocks': list(range(num_blocks)),
  'onset_idx': onset_idx,
  'num_blocks': num_blocks,
  'num_classes': 12,
  'num_subjects': 10,
  'stimulation_freq': [9.25, 11.25, 13.25, 9.75, 11.75, 13.75, 10.25,
                       12.25, 14.25, 10.75, 12.75, 14.75]
}

# %%
montage = mne.channels.make_standard_montage('standard_1020')
info = mne.create_info(ch_names=meta['channels'], sfreq=meta['recording_freq'], ch_types=['eeg'] * meta['num_channels'])

# %% [markdown]
# # Helper Functions

# %%
def get_epoch_data(patient_dict, electrode_type='wet'):
    '''
    Get epoched data from the patient json file
    Args:
        patient_dict: dictionary of the patient data
        electrode_type: "dry" or "wet" 
    Return:
        X: (blocks, num_classes, num_channels, timepoint)
        y: (blocks, num_classes)
    '''

    if electrode_type == 'dry':
        index = 0
    elif electrode_type == 'wet':
        index = 1
  
    X = patient_dict['data']
    X = X[:, :, index, :, :]
    X = X.transpose([2, 3, 0, 1])

    y = np.tile(np.arange(0, 12), [meta['num_blocks'], 1])

    return X, y

# %% [markdown]
# # Description of the dataset Wearable SSVEP BCI Dataset
# Wearable SSVEP Paper: https://www.mdpi.com/1424-8220/21/4/1256/pdf#:~:text=The%20dataset%20consists%20of%208,target%20SSVEP%2Dbased%20BCI%20task.&text=Besides%2C%20the%20dataset%20provides%20sufficient,of%20wearable%20SSVEP%2Dbased%20BCIs.
#
# FBCCA Paper: https://iopscience.iop.org/article/10.1088/1741-2560/12/4/046008/pdf
# * 10 blocks, 12 trials (i.e. targets) per block
# * 8 channels
# * y (0: class_1, 1: class_2, ... 11: class_12)
# * 250 Hz, 4 ms/timepoint
# * each trial is 2.84 s (0.5s before stimulus onset, 2s for stimulation, 0.14s visual latency, and 0.2s after stimulus offset), and is corresponding with each target [0, 1, 2, ... 11]

# %% [markdown]
# ## Load all patient data

# %%
data_path = "../data/arico_dataset"
patient_data = [scipy.io.loadmat(os.path.join(data_path, file)) for file in os.listdir(data_path) if ".mat" in file]

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_data(X_orig, l_freq, h_freq, notch_freq=None, method='fir', ref_type=None):
    '''
    Perform standard processing pipeline on the input data
    Args:
    X_orig: (blocks, num_classes, num_channels, timepoint)
    Return:
    X: (blocks, num_classes, num_channels, timepoint)
    ref_type: 'average', 'REST'
    '''
    X = np.zeros(X_orig.shape)
    for i in range(len(X)):
        X_slice = X_orig[i]

        # re-referencing
        if ref_type is not None:
            X_slice = mne.EpochsArray(X_orig[i].copy(), info=info, verbose=0, baseline=(None, None))
            X_slice.set_montage(montage)
            X_slice, _ = mne.set_eeg_reference(X_slice, ref_channels=ref_type, verbose=0)
        # notch-filtering
        if notch_freq is not None:
            X_slice = notch_filter(X_slice, Fs=meta['recording_freq'], freqs=notch_freq, verbose=0, method=method)
        # bandpassing
        X_slice = filter_data(X_slice, sfreq=meta['recording_freq'], l_freq=l_freq, h_freq=h_freq, verbose=0, method=method)

        X[i] = X_slice
    return X

# %%
# preprocess all subjects
X_all_subjects = np.zeros([len(patient_data), meta['num_blocks'], meta['num_classes'], meta['num_channels'], meta['epoch_length_timepoint']])
y_all_subjects = np.zeros([len(patient_data), meta['num_blocks'], meta['num_classes']])
l_freq = 7.25
h_freq = 90
notch_freq = 50
method = 'iir'
ref_type = 'average'

for i in range(len(X_all_subjects)):
    X_orig, y_orig = get_epoch_data(patient_data[i], electrode_type='wet')
    X = preprocess_data(X_orig, l_freq=l_freq, h_freq=h_freq, notch_freq=notch_freq, method=method, ref_type=ref_type)
    X_all_subjects[i] = X
    y_all_subjects[i] = y_orig

# %% [markdown]
# ## Take a look at single subject

# %% [markdown]
# SSVEPs at several frequencies from the Oz channel were averaged across all blocks for all subjects

# %%
freq_picks = [9.25, 9.75, 13.25]
freq_picks_string = ", ".join([str(x) for x in freq_picks])
channel = 'Oz'
subject_idx = 4
X = X_all_subjects[subject_idx]
X = X.mean(0)

# Time-domain analysis
target_avg_potentials = np.zeros([len(freq_picks), meta['epoch_length_timepoint']])
for i, freq_pick in enumerate(freq_picks):
    target_avg_potential = X[meta['stimulation_freq'].index(freq_pick), meta['channels'].index(channel), :]
    target_avg_potentials[i, :] = target_avg_potential
    
f, axes = plt.subplots(figsize=(24, 6), nrows=len(freq_picks), ncols=1, sharex=True, sharey=True)
if len(freq_picks) == 1:
    axes = [axes]

xticks = np.linspace(meta['epoch_start'], meta['epoch_start'] + meta['epoch_length'], meta['epoch_length_timepoint'])
for i, ax in enumerate(axes):
    sns.lineplot(x=xticks, y=target_avg_potentials[i], ax=ax, label=f'{freq_picks[i]} Hz');
    ax.set(ylabel='Amplitude (uV)')
    ax.axvline(x=meta['onset'], linestyle='--', color='gray')
    ax.legend(loc='upper right')
axes[0].set_title(f'Target flashing at {freq_picks_string} Hz')
axes[-1].set_xlabel('Time (ms)');
plt.tight_layout()

# %%
# FFT, Frequency-domain analysis
freqs = np.linspace(0.0, meta['recording_freq'] / 2, int(meta['epoch_length_timepoint'] / 2))
freq_avg_potential = fft(X)[:, :, 0: int(meta['epoch_length_timepoint'] / 2)]
freq_avg_potential = 2 / meta['epoch_length_timepoint'] * np.abs(freq_avg_potential)

plt.figure(figsize=(24, 6))
ax = plt.subplot()
xticks = freqs
for freq_pick in freq_picks:
    yticks = freq_avg_potential[meta['stimulation_freq'].index(freq_pick), meta['channels'].index(channel), :]
    sns.lineplot(x=xticks, y=yticks, ax=ax, label=f"{freq_pick} Hz")

ax.set_title(f'Target flashing at {freq_picks_string} Hz')
ax.set_xlabel('Frequency (Hz)')
ax.set_ylabel('Amplitude (uV)');

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### EEGNet

# %%
def EEGNet(nb_classes, Chans, Samples, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 
    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    model = Sequential()
    ##################################################################
    model.add(Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False))
    model.add(BatchNormalization())
    model.add(DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.)))
    model.add(BatchNormalization())
    model.add(Activation('elu'))
    model.add(AveragePooling2D((1, 4)))
    model.add(dropoutType(dropoutRate))
    
    model.add(SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same'))
    model.add(BatchNormalization())
    model.add(Activation('elu'))
    model.add(AveragePooling2D((1, 8)))
    model.add(dropoutType(dropoutRate))
        
    model.add(Flatten(name = 'flatten'))
    
    model.add(Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate)))
    model.add(Activation('softmax', name = 'softmax'))
    
    return model

# %% [markdown]
# #### Preprocessing
# X has to be the shape (num_data, channels, timepoints, 1) <br>
# y has to be the shape (num_data, class_num)

# %% [markdown]
# Let's do classification on one subject

# %%
subject_idx = 3
X_orig = X_all_subjects[subject_idx]
y_orig = y_all_subjects[subject_idx]
# reshape to required dimension
X_orig = X_orig[:, :, :, :, None]
X_orig.shape, y_orig.shape
# Out:
# ((10, 12, 8, 710, 1), (10, 12))

# %% [markdown]
# #### Training

# %%
epochs = 350
batch_size = 64
lr = 1e-4
dropoutRate = 0.4
model = EEGNet(nb_classes = meta['num_classes'], Chans = meta['num_channels'], 
            Samples = meta['epoch_length_timepoint'] - meta['onset_idx'], 
            dropoutRate = dropoutRate)  # only use data since event onset
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=lr), 
            metrics = ['acc'])
X = X_orig.reshape([-1, X_orig.shape[-3], X_orig.shape[-2], X_orig.shape[-1]])
X = X[:, :, meta['onset_idx']:, :]
num_train = int((meta['num_blocks'] - 1) * meta['num_classes'])  # ensure that the model has see each target at least (num_block - 2) times
X_train = X[:num_train] 
X_val = X[num_train:]

y = y_orig.reshape([-1])
y_train = y[:num_train]
y_val = y[num_train:]
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
# Out:
# Epoch 1/350
# 2/2 [==============================] - 2s 495ms/step - loss: 2.6095 - acc: 0.0556 - val_loss: 2.4922 - val_acc: 0.0833
# Epoch 2/350
# 2/2 [==============================] - 0s 212ms/step - loss: 2.5080 - acc: 0.1111 - val_loss: 2.4905 - val_acc: 0.0833
# Epoch 3/350
# 2/2 [==============================] - ETA: 0s - loss: 2.4917 - acc: 0.064 - 0s 201ms/step - loss: 2.4917 - acc: 0.0648 - val_loss: 2.4892 - val_acc: 0.1667
# Epoch 4/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.4870 - acc: 0.0741 - val_loss: 2.4880 - val_acc: 0.1667
# Epoch 5/350
# 2/2 [==============================] - 0s 211ms/step - loss: 2.4850 - acc: 0.0926 - val_loss: 2.4869 - val_acc: 0.1667
# Epoch 6/350
# 2/2 [==============================] - 0s 197ms/step - loss: 2.4870 - acc: 0.0741 - val_loss: 2.4859 - val_acc: 0.1667
# Epoch 7/350
# 2/2 [==============================] - 0s 208ms/step - loss: 2.4708 - acc: 0.1574 - val_loss: 2.4850 - val_acc: 0.1667
# Epoch 8/350
# 2/2 [==============================] - 0s 196ms/step - loss: 2.4758 - acc: 0.0648 - val_loss: 2.4842 - val_acc: 0.1667
# Epoch 9/350
# 2/2 [==============================] - 0s 214ms/step - loss: 2.4840 - acc: 0.0648 - val_loss: 2.4833 - val_acc: 0.1667
# Epoch 10/350
# 2/2 [==============================] - 0s 205ms/step - loss: 2.4849 - acc: 0.0648 - val_loss: 2.4825 - val_acc: 0.1667
# Epoch 11/350
# 2/2 [==============================] - 0s 193ms/step - loss: 2.4630 - acc: 0.1204 - val_loss: 2.4817 - val_acc: 0.1667
# Epoch 12/350
# 2/2 [==============================] - 0s 203ms/step - loss: 2.4598 - acc: 0.1204 - val_loss: 2.4809 - val_acc: 0.1667
# Epoch 13/350
# 2/2 [==============================] - 0s 212ms/step - loss: 2.4791 - acc: 0.1111 - val_loss: 2.4801 - val_acc: 0.1667
# Epoch 14/350
# 2/2 [==============================] - 0s 214ms/step - loss: 2.4659 - acc: 0.1019 - val_loss: 2.4793 - val_acc: 0.1667
# Epoch 15/350
# 2/2 [==============================] - 0s 208ms/step - loss: 2.4681 - acc: 0.1204 - val_loss: 2.4786 - val_acc: 0.1667
# Epoch 16/350
# 2/2 [==============================] - 0s 203ms/step - loss: 2.4613 - acc: 0.1111 - val_loss: 2.4778 - val_acc: 0.1667
# Epoch 17/350
# 2/2 [==============================] - 0s 208ms/step - loss: 2.4547 - acc: 0.1481 - val_loss: 2.4770 - val_acc: 0.1667
# Epoch 18/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.4786 - acc: 0.0833 - val_loss: 2.4762 - val_acc: 0.1667
# Epoch 19/350
# 2/2 [==============================] - 0s 208ms/step - loss: 2.4667 - acc: 0.1204 - val_loss: 2.4754 - val_acc: 0.1667
# Epoch 20/350
# 2/2 [==============================] - 0s 202ms/step - loss: 2.4547 - acc: 0.1481 - val_loss: 2.4746 - val_acc: 0.1667
# Epoch 21/350
# 2/2 [==============================] - 0s 210ms/step - loss: 2.4456 - acc: 0.1389 - val_loss: 2.4738 - val_acc: 0.2500
# Epoch 22/350
# 2/2 [==============================] - 0s 197ms/step - loss: 2.4373 - acc: 0.2037 - val_loss: 2.4729 - val_acc: 0.2500
# Epoch 23/350
# 2/2 [==============================] - 0s 203ms/step - loss: 2.4395 - acc: 0.1574 - val_loss: 2.4721 - val_acc: 0.3333
# Epoch 24/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.4463 - acc: 0.1296 - val_loss: 2.4712 - val_acc: 0.3333
# Epoch 25/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.4546 - acc: 0.1296 - val_loss: 2.4703 - val_acc: 0.3333
# Epoch 26/350
# 2/2 [==============================] - 0s 198ms/step - loss: 2.4527 - acc: 0.1204 - val_loss: 2.4695 - val_acc: 0.3333
# Epoch 27/350
# 2/2 [==============================] - 0s 205ms/step - loss: 2.4424 - acc: 0.1759 - val_loss: 2.4686 - val_acc: 0.3333
# Epoch 28/350
# 2/2 [==============================] - 0s 154ms/step - loss: 2.4448 - acc: 0.2130 - val_loss: 2.4676 - val_acc: 0.3333
# Epoch 29/350
# 2/2 [==============================] - 0s 205ms/step - loss: 2.4366 - acc: 0.1759 - val_loss: 2.4667 - val_acc: 0.3333
# Epoch 30/350
# 2/2 [==============================] - 0s 205ms/step - loss: 2.4295 - acc: 0.2407 - val_loss: 2.4657 - val_acc: 0.3333
# Epoch 31/350
# 2/2 [==============================] - 0s 207ms/step - loss: 2.4287 - acc: 0.2037 - val_loss: 2.4647 - val_acc: 0.3333
# Epoch 32/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.4208 - acc: 0.2593 - val_loss: 2.4636 - val_acc: 0.3333
# Epoch 33/350
# 2/2 [==============================] - 0s 204ms/step - loss: 2.4257 - acc: 0.1852 - val_loss: 2.4625 - val_acc: 0.3333
# Epoch 34/350
# 2/2 [==============================] - 0s 204ms/step - loss: 2.4179 - acc: 0.1944 - val_loss: 2.4614 - val_acc: 0.3333
# Epoch 35/350
# 2/2 [==============================] - 0s 207ms/step - loss: 2.4248 - acc: 0.2037 - val_loss: 2.4602 - val_acc: 0.3333
# Epoch 36/350
# 2/2 [==============================] - 0s 206ms/step - loss: 2.4206 - acc: 0.2130 - val_loss: 2.4590 - val_acc: 0.3333
# Epoch 37/350
# 2/2 [==============================] - 0s 191ms/step - loss: 2.4166 - acc: 0.2130 - val_loss: 2.4578 - val_acc: 0.3333
# Epoch 38/350
# 2/2 [==============================] - 0s 218ms/step - loss: 2.4032 - acc: 0.2593 - val_loss: 2.4565 - val_acc: 0.3333
# Epoch 39/350
# 2/2 [==============================] - 0s 143ms/step - loss: 2.4062 - acc: 0.1852 - val_loss: 2.4552 - val_acc: 0.3333
# Epoch 40/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.3894 - acc: 0.2685 - val_loss: 2.4539 - val_acc: 0.3333
# Epoch 41/350
# 2/2 [==============================] - 0s 196ms/step - loss: 2.4094 - acc: 0.2593 - val_loss: 2.4525 - val_acc: 0.3333
# Epoch 42/350
# 2/2 [==============================] - 0s 199ms/step - loss: 2.3918 - acc: 0.2963 - val_loss: 2.4510 - val_acc: 0.4167
# Epoch 43/350
# 2/2 [==============================] - 0s 214ms/step - loss: 2.4163 - acc: 0.1944 - val_loss: 2.4495 - val_acc: 0.4167
# Epoch 44/350
# 2/2 [==============================] - 0s 204ms/step - loss: 2.3922 - acc: 0.2963 - val_loss: 2.4479 - val_acc: 0.4167
# Epoch 45/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.3842 - acc: 0.3426 - val_loss: 2.4464 - val_acc: 0.4167
# Epoch 46/350
# 2/2 [==============================] - 0s 173ms/step - loss: 2.3942 - acc: 0.2778 - val_loss: 2.4447 - val_acc: 0.4167
# Epoch 47/350
# 2/2 [==============================] - 0s 198ms/step - loss: 2.3894 - acc: 0.2963 - val_loss: 2.4430 - val_acc: 0.4167
# Epoch 48/350
# 2/2 [==============================] - 0s 205ms/step - loss: 2.3808 - acc: 0.2685 - val_loss: 2.4413 - val_acc: 0.4167
# Epoch 49/350
# 2/2 [==============================] - 0s 198ms/step - loss: 2.3847 - acc: 0.2870 - val_loss: 2.4394 - val_acc: 0.4167
# Epoch 50/350
# 2/2 [==============================] - 0s 211ms/step - loss: 2.3856 - acc: 0.2870 - val_loss: 2.4375 - val_acc: 0.4167
# Epoch 51/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.3718 - acc: 0.3148 - val_loss: 2.4356 - val_acc: 0.5000
# Epoch 52/350
# 2/2 [==============================] - 0s 191ms/step - loss: 2.3600 - acc: 0.4259 - val_loss: 2.4336 - val_acc: 0.5000
# Epoch 53/350
# 2/2 [==============================] - 0s 201ms/step - loss: 2.3687 - acc: 0.3519 - val_loss: 2.4315 - val_acc: 0.5000
# Epoch 54/350
# 2/2 [==============================] - 0s 199ms/step - loss: 2.3740 - acc: 0.3333 - val_loss: 2.4294 - val_acc: 0.5000
# Epoch 55/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.3839 - acc: 0.2963 - val_loss: 2.4273 - val_acc: 0.5000
# Epoch 56/350
# 2/2 [==============================] - 0s 195ms/step - loss: 2.3676 - acc: 0.3704 - val_loss: 2.4251 - val_acc: 0.5000
# Epoch 57/350
# 2/2 [==============================] - 0s 198ms/step - loss: 2.3628 - acc: 0.3704 - val_loss: 2.4228 - val_acc: 0.5000
# Epoch 58/350
# 2/2 [==============================] - 0s 196ms/step - loss: 2.3569 - acc: 0.3981 - val_loss: 2.4205 - val_acc: 0.5000
# Epoch 59/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.3500 - acc: 0.3796 - val_loss: 2.4182 - val_acc: 0.5000
# Epoch 60/350
# 2/2 [==============================] - 0s 197ms/step - loss: 2.3478 - acc: 0.3148 - val_loss: 2.4158 - val_acc: 0.5000
# Epoch 61/350
# 2/2 [==============================] - 0s 197ms/step - loss: 2.3585 - acc: 0.3333 - val_loss: 2.4134 - val_acc: 0.5000
# Epoch 62/350
# 2/2 [==============================] - 0s 196ms/step - loss: 2.3476 - acc: 0.3796 - val_loss: 2.4109 - val_acc: 0.5000
# Epoch 63/350
# 2/2 [==============================] - 0s 189ms/step - loss: 2.3506 - acc: 0.3426 - val_loss: 2.4083 - val_acc: 0.5000
# Epoch 64/350
# 2/2 [==============================] - 0s 192ms/step - loss: 2.3562 - acc: 0.3426 - val_loss: 2.4057 - val_acc: 0.5000
# Epoch 65/350
# 2/2 [==============================] - 0s 200ms/step - loss: 2.3407 - acc: 0.3704 - val_loss: 2.4031 - val_acc: 0.5000
# Epoch 66/350
# 2/2 [==============================] - 0s 185ms/step - loss: 2.3342 - acc: 0.3981 - val_loss: 2.4003 - val_acc: 0.5000
# Epoch 67/350
# 2/2 [==============================] - 0s 216ms/step - loss: 2.3338 - acc: 0.3981 - val_loss: 2.3975 - val_acc: 0.5000
# Epoch 68/350
# 2/2 [==============================] - 0s 194ms/step - loss: 2.3399 - acc: 0.4259 - val_loss: 2.3946 - val_acc: 0.5000
# Epoch 69/350
# 2/2 [==============================] - 0s 172ms/step - loss: 2.3298 - acc: 0.4259 - val_loss: 2.3918 - val_acc: 0.5000
# Epoch 70/350
# 2/2 [==============================] - 0s 161ms/step - loss: 2.3218 - acc: 0.4537 - val_loss: 2.3889 - val_acc: 0.5000
# Epoch 71/350
# 2/2 [==============================] - 0s 221ms/step - loss: 2.3248 - acc: 0.4259 - val_loss: 2.3858 - val_acc: 0.5000
# Epoch 72/350
# 2/2 [==============================] - 0s 226ms/step - loss: 2.3286 - acc: 0.3981 - val_loss: 2.3828 - val_acc: 0.5000
# Epoch 73/350
# 2/2 [==============================] - 0s 160ms/step - loss: 2.3115 - acc: 0.4444 - val_loss: 2.3797 - val_acc: 0.5000
# Epoch 74/350
# 2/2 [==============================] - 0s 156ms/step - loss: 2.3172 - acc: 0.3611 - val_loss: 2.3766 - val_acc: 0.5833
# Epoch 75/350
# 2/2 [==============================] - 0s 159ms/step - loss: 2.3061 - acc: 0.4444 - val_loss: 2.3735 - val_acc: 0.5833
# Epoch 76/350
# 2/2 [==============================] - 0s 155ms/step - loss: 2.3188 - acc: 0.3796 - val_loss: 2.3701 - val_acc: 0.5833
# Epoch 77/350
# 2/2 [==============================] - 0s 166ms/step - loss: 2.3060 - acc: 0.5463 - val_loss: 2.3669 - val_acc: 0.5833
# Epoch 78/350
# 2/2 [==============================] - 0s 151ms/step - loss: 2.3097 - acc: 0.4259 - val_loss: 2.3635 - val_acc: 0.5833
# Epoch 79/350
# 2/2 [==============================] - 0s 129ms/step - loss: 2.3075 - acc: 0.4722 - val_loss: 2.3601 - val_acc: 0.5833
# Epoch 80/350
# 2/2 [==============================] - 0s 127ms/step - loss: 2.3115 - acc: 0.4630 - val_loss: 2.3566 - val_acc: 0.5833
# Epoch 81/350
# 2/2 [==============================] - 0s 188ms/step - loss: 2.2827 - acc: 0.5185 - val_loss: 2.3532 - val_acc: 0.5833
# Epoch 82/350
# 2/2 [==============================] - 0s 148ms/step - loss: 2.2907 - acc: 0.4537 - val_loss: 2.3497 - val_acc: 0.5833
# Epoch 83/350
# 2/2 [==============================] - 0s 133ms/step - loss: 2.2977 - acc: 0.4630 - val_loss: 2.3462 - val_acc: 0.5833
# Epoch 84/350
# 2/2 [==============================] - 0s 195ms/step - loss: 2.2912 - acc: 0.4259 - val_loss: 2.3428 - val_acc: 0.5833
# Epoch 85/350
# 2/2 [==============================] - 0s 141ms/step - loss: 2.2863 - acc: 0.5278 - val_loss: 2.3392 - val_acc: 0.5833
# Epoch 86/350
# 2/2 [==============================] - 0s 153ms/step - loss: 2.2852 - acc: 0.5093 - val_loss: 2.3357 - val_acc: 0.5833
# Epoch 87/350
# 2/2 [==============================] - 0s 144ms/step - loss: 2.2839 - acc: 0.5278 - val_loss: 2.3321 - val_acc: 0.5833
# Epoch 88/350
# 2/2 [==============================] - 0s 122ms/step - loss: 2.2687 - acc: 0.4907 - val_loss: 2.3285 - val_acc: 0.5833
# Epoch 89/350
# 2/2 [==============================] - 0s 136ms/step - loss: 2.2782 - acc: 0.4722 - val_loss: 2.3250 - val_acc: 0.5833
# Epoch 90/350
# 2/2 [==============================] - 0s 134ms/step - loss: 2.2714 - acc: 0.5278 - val_loss: 2.3213 - val_acc: 0.5833
# Epoch 91/350
# 2/2 [==============================] - 0s 150ms/step - loss: 2.2721 - acc: 0.5278 - val_loss: 2.3176 - val_acc: 0.5833
# Epoch 92/350
# 2/2 [==============================] - 0s 147ms/step - loss: 2.2631 - acc: 0.4907 - val_loss: 2.3140 - val_acc: 0.5833
# Epoch 93/350
# 2/2 [==============================] - 0s 146ms/step - loss: 2.2729 - acc: 0.5185 - val_loss: 2.3102 - val_acc: 0.5833
# Epoch 94/350
# 2/2 [==============================] - 0s 134ms/step - loss: 2.2540 - acc: 0.5648 - val_loss: 2.3064 - val_acc: 0.5833
# Epoch 95/350
# 2/2 [==============================] - 0s 149ms/step - loss: 2.2660 - acc: 0.5370 - val_loss: 2.3026 - val_acc: 0.5833
# Epoch 96/350
# 2/2 [==============================] - 0s 165ms/step - loss: 2.2769 - acc: 0.4815 - val_loss: 2.2989 - val_acc: 0.5833
# Epoch 97/350
# 2/2 [==============================] - 0s 143ms/step - loss: 2.2508 - acc: 0.5278 - val_loss: 2.2951 - val_acc: 0.5833
# Epoch 98/350
# 2/2 [==============================] - 0s 162ms/step - loss: 2.2635 - acc: 0.4352 - val_loss: 2.2913 - val_acc: 0.5833
# Epoch 99/350
# 2/2 [==============================] - 0s 133ms/step - loss: 2.2455 - acc: 0.5370 - val_loss: 2.2876 - val_acc: 0.5833
# Epoch 100/350
# 2/2 [==============================] - 0s 174ms/step - loss: 2.2371 - acc: 0.6111 - val_loss: 2.2837 - val_acc: 0.5833
# Epoch 101/350
# 2/2 [==============================] - 0s 196ms/step - loss: 2.2513 - acc: 0.5556 - val_loss: 2.2799 - val_acc: 0.5833
# Epoch 102/350
# 2/2 [==============================] - 0s 127ms/step - loss: 2.2467 - acc: 0.5741 - val_loss: 2.2763 - val_acc: 0.5833
# Epoch 103/350
# 2/2 [==============================] - 0s 119ms/step - loss: 2.2426 - acc: 0.5000 - val_loss: 2.2726 - val_acc: 0.5833
# Epoch 104/350
# 2/2 [==============================] - 0s 119ms/step - loss: 2.2288 - acc: 0.5370 - val_loss: 2.2688 - val_acc: 0.6667
# Epoch 105/350
# 2/2 [==============================] - 0s 170ms/step - loss: 2.2388 - acc: 0.5648 - val_loss: 2.2651 - val_acc: 0.6667
# Epoch 106/350
# 2/2 [==============================] - 0s 162ms/step - loss: 2.2237 - acc: 0.6111 - val_loss: 2.2614 - val_acc: 0.6667
# Epoch 107/350
# 2/2 [==============================] - 0s 134ms/step - loss: 2.2277 - acc: 0.5370 - val_loss: 2.2578 - val_acc: 0.6667
# Epoch 108/350
# 2/2 [==============================] - 0s 147ms/step - loss: 2.2328 - acc: 0.5370 - val_loss: 2.2541 - val_acc: 0.6667
# Epoch 109/350
# 2/2 [==============================] - 0s 165ms/step - loss: 2.2322 - acc: 0.5185 - val_loss: 2.2504 - val_acc: 0.6667
# Epoch 110/350
# 2/2 [==============================] - 0s 146ms/step - loss: 2.2250 - acc: 0.5556 - val_loss: 2.2467 - val_acc: 0.6667
# Epoch 111/350
# 2/2 [==============================] - 0s 133ms/step - loss: 2.2228 - acc: 0.6389 - val_loss: 2.2432 - val_acc: 0.6667
# Epoch 112/350
# 2/2 [==============================] - 0s 140ms/step - loss: 2.2243 - acc: 0.5000 - val_loss: 2.2396 - val_acc: 0.6667
# Epoch 113/350
# 2/2 [==============================] - 0s 128ms/step - loss: 2.2107 - acc: 0.6111 - val_loss: 2.2361 - val_acc: 0.6667
# Epoch 114/350
# 2/2 [==============================] - 0s 157ms/step - loss: 2.2172 - acc: 0.5926 - val_loss: 2.2327 - val_acc: 0.6667
# Epoch 115/350
# 2/2 [==============================] - 0s 149ms/step - loss: 2.2103 - acc: 0.5648 - val_loss: 2.2291 - val_acc: 0.6667
# Epoch 116/350
# 2/2 [==============================] - 0s 165ms/step - loss: 2.2136 - acc: 0.5926 - val_loss: 2.2255 - val_acc: 0.6667
# Epoch 117/350
# 2/2 [==============================] - 0s 162ms/step - loss: 2.1761 - acc: 0.6667 - val_loss: 2.2218 - val_acc: 0.6667
# Epoch 118/350
# 2/2 [==============================] - 0s 126ms/step - loss: 2.1909 - acc: 0.6204 - val_loss: 2.2182 - val_acc: 0.6667
# Epoch 119/350
# 2/2 [==============================] - 0s 143ms/step - loss: 2.1813 - acc: 0.5648 - val_loss: 2.2145 - val_acc: 0.6667
# Epoch 120/350
# 2/2 [==============================] - 0s 147ms/step - loss: 2.1900 - acc: 0.6296 - val_loss: 2.2109 - val_acc: 0.6667
# Epoch 121/350
# 2/2 [==============================] - 0s 116ms/step - loss: 2.1937 - acc: 0.5833 - val_loss: 2.2074 - val_acc: 0.6667
# Epoch 122/350
# 2/2 [==============================] - 0s 190ms/step - loss: 2.2038 - acc: 0.6389 - val_loss: 2.2037 - val_acc: 0.6667
# Epoch 123/350
# 2/2 [==============================] - 0s 120ms/step - loss: 2.1828 - acc: 0.6019 - val_loss: 2.2002 - val_acc: 0.6667
# Epoch 124/350
# 2/2 [==============================] - 0s 113ms/step - loss: 2.1799 - acc: 0.6111 - val_loss: 2.1967 - val_acc: 0.6667
# Epoch 125/350
# 2/2 [==============================] - 0s 125ms/step - loss: 2.1546 - acc: 0.6389 - val_loss: 2.1930 - val_acc: 0.6667
# Epoch 126/350
# 2/2 [==============================] - 0s 173ms/step - loss: 2.1951 - acc: 0.5833 - val_loss: 2.1896 - val_acc: 0.6667
# Epoch 127/350
# 2/2 [==============================] - 0s 131ms/step - loss: 2.1935 - acc: 0.6296 - val_loss: 2.1863 - val_acc: 0.6667
# Epoch 128/350
# 2/2 [==============================] - 0s 104ms/step - loss: 2.1833 - acc: 0.6204 - val_loss: 2.1831 - val_acc: 0.6667
# Epoch 129/350
# 2/2 [==============================] - 0s 159ms/step - loss: 2.1774 - acc: 0.6574 - val_loss: 2.1798 - val_acc: 0.6667
# Epoch 130/350
# 2/2 [==============================] - 0s 114ms/step - loss: 2.1737 - acc: 0.6204 - val_loss: 2.1765 - val_acc: 0.6667
# Epoch 131/350
# 2/2 [==============================] - 0s 145ms/step - loss: 2.1555 - acc: 0.6481 - val_loss: 2.1733 - val_acc: 0.6667
# Epoch 132/350
# 2/2 [==============================] - 0s 124ms/step - loss: 2.1561 - acc: 0.6574 - val_loss: 2.1700 - val_acc: 0.6667
# Epoch 133/350
# 2/2 [==============================] - 0s 167ms/step - loss: 2.1661 - acc: 0.6481 - val_loss: 2.1669 - val_acc: 0.6667
# Epoch 134/350
# 2/2 [==============================] - 0s 155ms/step - loss: 2.1625 - acc: 0.6481 - val_loss: 2.1638 - val_acc: 0.6667
# Epoch 135/350
# 2/2 [==============================] - 0s 152ms/step - loss: 2.1543 - acc: 0.6667 - val_loss: 2.1607 - val_acc: 0.6667
# Epoch 136/350
# 2/2 [==============================] - 0s 157ms/step - loss: 2.1483 - acc: 0.6019 - val_loss: 2.1578 - val_acc: 0.6667
# Epoch 137/350
# 2/2 [==============================] - 0s 124ms/step - loss: 2.1583 - acc: 0.6019 - val_loss: 2.1549 - val_acc: 0.6667
# Epoch 138/350
# 2/2 [==============================] - 0s 111ms/step - loss: 2.1524 - acc: 0.6667 - val_loss: 2.1519 - val_acc: 0.6667
# Epoch 139/350
# 2/2 [==============================] - 0s 129ms/step - loss: 2.1467 - acc: 0.6389 - val_loss: 2.1488 - val_acc: 0.6667
# Epoch 140/350
# 2/2 [==============================] - 0s 144ms/step - loss: 2.1321 - acc: 0.7500 - val_loss: 2.1456 - val_acc: 0.6667
# Epoch 141/350
# 2/2 [==============================] - 0s 115ms/step - loss: 2.1493 - acc: 0.5926 - val_loss: 2.1424 - val_acc: 0.6667
# Epoch 142/350
# 2/2 [==============================] - 0s 147ms/step - loss: 2.1383 - acc: 0.6852 - val_loss: 2.1395 - val_acc: 0.6667
# Epoch 143/350
# 2/2 [==============================] - 0s 122ms/step - loss: 2.1300 - acc: 0.6574 - val_loss: 2.1366 - val_acc: 0.6667
# Epoch 144/350
# 2/2 [==============================] - 0s 130ms/step - loss: 2.1277 - acc: 0.6759 - val_loss: 2.1337 - val_acc: 0.6667
# Epoch 145/350
# 2/2 [==============================] - 0s 106ms/step - loss: 2.1302 - acc: 0.7130 - val_loss: 2.1306 - val_acc: 0.6667
# Epoch 146/350
# 2/2 [==============================] - 0s 108ms/step - loss: 2.1359 - acc: 0.7315 - val_loss: 2.1277 - val_acc: 0.6667
# Epoch 147/350
# 2/2 [==============================] - 0s 123ms/step - loss: 2.1014 - acc: 0.7315 - val_loss: 2.1247 - val_acc: 0.6667
# Epoch 148/350
# 2/2 [==============================] - 0s 116ms/step - loss: 2.1163 - acc: 0.7315 - val_loss: 2.1219 - val_acc: 0.6667
# Epoch 149/350
# 2/2 [==============================] - 0s 105ms/step - loss: 2.1249 - acc: 0.7315 - val_loss: 2.1189 - val_acc: 0.6667
# Epoch 150/350
# 2/2 [==============================] - 0s 143ms/step - loss: 2.0971 - acc: 0.6667 - val_loss: 2.1159 - val_acc: 0.6667
# Epoch 151/350
# 2/2 [==============================] - 0s 112ms/step - loss: 2.1190 - acc: 0.6944 - val_loss: 2.1129 - val_acc: 0.6667
# Epoch 152/350
# 2/2 [==============================] - 0s 173ms/step - loss: 2.1031 - acc: 0.7315 - val_loss: 2.1101 - val_acc: 0.6667
# Epoch 153/350
# 2/2 [==============================] - 0s 128ms/step - loss: 2.1263 - acc: 0.6389 - val_loss: 2.1073 - val_acc: 0.6667
# Epoch 154/350
# 2/2 [==============================] - 0s 111ms/step - loss: 2.1037 - acc: 0.6944 - val_loss: 2.1044 - val_acc: 0.6667
# Epoch 155/350
# 2/2 [==============================] - 0s 129ms/step - loss: 2.0858 - acc: 0.7130 - val_loss: 2.1015 - val_acc: 0.6667
# Epoch 156/350
# 2/2 [==============================] - 0s 136ms/step - loss: 2.0868 - acc: 0.7593 - val_loss: 2.0987 - val_acc: 0.6667
# Epoch 157/350
# 2/2 [==============================] - 0s 114ms/step - loss: 2.0853 - acc: 0.7130 - val_loss: 2.0959 - val_acc: 0.6667
# Epoch 158/350
# 2/2 [==============================] - 0s 113ms/step - loss: 2.0749 - acc: 0.6944 - val_loss: 2.0931 - val_acc: 0.6667
# Epoch 159/350
# 2/2 [==============================] - 0s 163ms/step - loss: 2.1152 - acc: 0.7500 - val_loss: 2.0902 - val_acc: 0.6667
# Epoch 160/350
# 2/2 [==============================] - 0s 121ms/step - loss: 2.0754 - acc: 0.7407 - val_loss: 2.0873 - val_acc: 0.6667
# Epoch 161/350
# 2/2 [==============================] - 0s 170ms/step - loss: 2.0837 - acc: 0.7407 - val_loss: 2.0843 - val_acc: 0.6667
# Epoch 162/350
# 2/2 [==============================] - 0s 114ms/step - loss: 2.0990 - acc: 0.6574 - val_loss: 2.0816 - val_acc: 0.6667
# Epoch 163/350
# 2/2 [==============================] - 0s 109ms/step - loss: 2.0833 - acc: 0.7222 - val_loss: 2.0787 - val_acc: 0.6667
# Epoch 164/350
# 2/2 [==============================] - 0s 110ms/step - loss: 2.0813 - acc: 0.7315 - val_loss: 2.0758 - val_acc: 0.6667
# Epoch 165/350
# 2/2 [==============================] - 0s 108ms/step - loss: 2.0732 - acc: 0.7315 - val_loss: 2.0729 - val_acc: 0.6667
# Epoch 166/350
# 2/2 [==============================] - 0s 122ms/step - loss: 2.0621 - acc: 0.7037 - val_loss: 2.0700 - val_acc: 0.6667
# Epoch 167/350
# 2/2 [==============================] - 0s 162ms/step - loss: 2.0592 - acc: 0.7130 - val_loss: 2.0671 - val_acc: 0.6667
# Epoch 168/350
# 2/2 [==============================] - 0s 127ms/step - loss: 2.0572 - acc: 0.7685 - val_loss: 2.0642 - val_acc: 0.6667
# Epoch 169/350
# 2/2 [==============================] - 0s 116ms/step - loss: 2.0548 - acc: 0.7407 - val_loss: 2.0613 - val_acc: 0.6667
# Epoch 170/350
# 2/2 [==============================] - 0s 152ms/step - loss: 2.0767 - acc: 0.7500 - val_loss: 2.0583 - val_acc: 0.6667
# Epoch 171/350
# 2/2 [==============================] - 0s 134ms/step - loss: 2.0541 - acc: 0.7593 - val_loss: 2.0551 - val_acc: 0.6667
# Epoch 172/350
# 2/2 [==============================] - 0s 175ms/step - loss: 2.0605 - acc: 0.6852 - val_loss: 2.0519 - val_acc: 0.6667
# Epoch 173/350
# 2/2 [==============================] - 0s 125ms/step - loss: 2.0500 - acc: 0.7130 - val_loss: 2.0487 - val_acc: 0.6667
# Epoch 174/350
# 2/2 [==============================] - 0s 142ms/step - loss: 2.0515 - acc: 0.7778 - val_loss: 2.0454 - val_acc: 0.6667
# Epoch 175/350
# 2/2 [==============================] - 0s 138ms/step - loss: 2.0681 - acc: 0.7407 - val_loss: 2.0424 - val_acc: 0.6667
# Epoch 176/350
# 2/2 [==============================] - 0s 141ms/step - loss: 2.0603 - acc: 0.7500 - val_loss: 2.0395 - val_acc: 0.6667
# Epoch 177/350
# 2/2 [==============================] - 0s 114ms/step - loss: 2.0520 - acc: 0.7037 - val_loss: 2.0365 - val_acc: 0.6667
# Epoch 178/350
# 2/2 [==============================] - 0s 148ms/step - loss: 2.0376 - acc: 0.7315 - val_loss: 2.0333 - val_acc: 0.6667
# Epoch 179/350
# 2/2 [==============================] - 0s 110ms/step - loss: 2.0315 - acc: 0.7593 - val_loss: 2.0301 - val_acc: 0.6667
# Epoch 180/350
# 2/2 [==============================] - 0s 124ms/step - loss: 2.0418 - acc: 0.7315 - val_loss: 2.0272 - val_acc: 0.6667
# Epoch 181/350
# 2/2 [==============================] - 0s 142ms/step - loss: 2.0306 - acc: 0.7870 - val_loss: 2.0244 - val_acc: 0.6667
# Epoch 182/350
# 2/2 [==============================] - 0s 130ms/step - loss: 2.0224 - acc: 0.7407 - val_loss: 2.0213 - val_acc: 0.6667
# Epoch 183/350
# 2/2 [==============================] - 0s 118ms/step - loss: 2.0073 - acc: 0.7130 - val_loss: 2.0184 - val_acc: 0.6667
# Epoch 184/350
# 2/2 [==============================] - 0s 126ms/step - loss: 2.0240 - acc: 0.7500 - val_loss: 2.0160 - val_acc: 0.6667
# Epoch 185/350
# 2/2 [==============================] - 0s 112ms/step - loss: 2.0295 - acc: 0.7500 - val_loss: 2.0132 - val_acc: 0.6667
# Epoch 186/350
# 2/2 [==============================] - 0s 119ms/step - loss: 1.9959 - acc: 0.7870 - val_loss: 2.0105 - val_acc: 0.6667
# Epoch 187/350
# 2/2 [==============================] - 0s 113ms/step - loss: 2.0130 - acc: 0.7500 - val_loss: 2.0078 - val_acc: 0.6667
# Epoch 188/350
# 2/2 [==============================] - 0s 122ms/step - loss: 2.0121 - acc: 0.6944 - val_loss: 2.0050 - val_acc: 0.6667
# Epoch 189/350
# 2/2 [==============================] - 0s 115ms/step - loss: 2.0224 - acc: 0.7315 - val_loss: 2.0021 - val_acc: 0.6667
# Epoch 190/350
# 2/2 [==============================] - 0s 130ms/step - loss: 2.0228 - acc: 0.6852 - val_loss: 1.9993 - val_acc: 0.6667
# Epoch 191/350
# 2/2 [==============================] - 0s 115ms/step - loss: 2.0106 - acc: 0.7407 - val_loss: 1.9968 - val_acc: 0.6667
# Epoch 192/350
# 2/2 [==============================] - 0s 110ms/step - loss: 1.9872 - acc: 0.7870 - val_loss: 1.9940 - val_acc: 0.6667
# Epoch 193/350
# 2/2 [==============================] - 0s 128ms/step - loss: 1.9902 - acc: 0.7963 - val_loss: 1.9912 - val_acc: 0.6667
# Epoch 194/350
# 2/2 [==============================] - 0s 108ms/step - loss: 1.9972 - acc: 0.7130 - val_loss: 1.9884 - val_acc: 0.6667
# Epoch 195/350
# 2/2 [==============================] - 0s 133ms/step - loss: 1.9982 - acc: 0.7870 - val_loss: 1.9858 - val_acc: 0.6667
# Epoch 196/350
# 2/2 [==============================] - 0s 108ms/step - loss: 1.9789 - acc: 0.8333 - val_loss: 1.9832 - val_acc: 0.6667
# Epoch 197/350
# 2/2 [==============================] - 0s 111ms/step - loss: 1.9853 - acc: 0.7778 - val_loss: 1.9806 - val_acc: 0.6667
# Epoch 198/350
# 2/2 [==============================] - 0s 108ms/step - loss: 1.9734 - acc: 0.7870 - val_loss: 1.9777 - val_acc: 0.6667
# Epoch 199/350
# 2/2 [==============================] - 0s 134ms/step - loss: 1.9763 - acc: 0.7685 - val_loss: 1.9747 - val_acc: 0.6667
# Epoch 200/350
# 2/2 [==============================] - 0s 144ms/step - loss: 1.9871 - acc: 0.7963 - val_loss: 1.9713 - val_acc: 0.6667
# Epoch 201/350
# 2/2 [==============================] - 0s 120ms/step - loss: 1.9719 - acc: 0.8148 - val_loss: 1.9683 - val_acc: 0.6667
# Epoch 202/350
# 2/2 [==============================] - 0s 107ms/step - loss: 1.9603 - acc: 0.7963 - val_loss: 1.9651 - val_acc: 0.6667
# Epoch 203/350
# 2/2 [==============================] - 0s 151ms/step - loss: 1.9619 - acc: 0.8148 - val_loss: 1.9617 - val_acc: 0.6667
# Epoch 204/350
# 2/2 [==============================] - 0s 142ms/step - loss: 1.9617 - acc: 0.7593 - val_loss: 1.9583 - val_acc: 0.6667
# Epoch 205/350
# 2/2 [==============================] - 0s 107ms/step - loss: 1.9539 - acc: 0.7778 - val_loss: 1.9548 - val_acc: 0.6667
# Epoch 206/350
# 2/2 [==============================] - 0s 132ms/step - loss: 1.9594 - acc: 0.7870 - val_loss: 1.9513 - val_acc: 0.6667
# Epoch 207/350
# 2/2 [==============================] - 0s 131ms/step - loss: 1.9306 - acc: 0.7963 - val_loss: 1.9476 - val_acc: 0.6667
# Epoch 208/350
# 2/2 [==============================] - 0s 154ms/step - loss: 1.9558 - acc: 0.7500 - val_loss: 1.9441 - val_acc: 0.6667
# Epoch 209/350
# 2/2 [==============================] - 0s 110ms/step - loss: 1.9592 - acc: 0.7685 - val_loss: 1.9399 - val_acc: 0.6667
# Epoch 210/350
# 2/2 [==============================] - 0s 128ms/step - loss: 1.9398 - acc: 0.7870 - val_loss: 1.9358 - val_acc: 0.6667
# Epoch 211/350
# 2/2 [==============================] - 0s 157ms/step - loss: 1.9206 - acc: 0.8148 - val_loss: 1.9320 - val_acc: 0.6667
# Epoch 212/350
# 2/2 [==============================] - 0s 115ms/step - loss: 1.9301 - acc: 0.7870 - val_loss: 1.9281 - val_acc: 0.6667
# Epoch 213/350
# 2/2 [==============================] - 0s 129ms/step - loss: 1.9263 - acc: 0.7500 - val_loss: 1.9244 - val_acc: 0.6667
# Epoch 214/350
# 2/2 [==============================] - 0s 107ms/step - loss: 1.9153 - acc: 0.7407 - val_loss: 1.9206 - val_acc: 0.6667
# Epoch 215/350
# 2/2 [==============================] - 0s 107ms/step - loss: 1.9032 - acc: 0.7963 - val_loss: 1.9172 - val_acc: 0.6667
# Epoch 216/350
# 2/2 [==============================] - 0s 166ms/step - loss: 1.9153 - acc: 0.7870 - val_loss: 1.9141 - val_acc: 0.6667
# Epoch 217/350
# 2/2 [==============================] - 0s 141ms/step - loss: 1.9114 - acc: 0.7500 - val_loss: 1.9108 - val_acc: 0.6667
# Epoch 218/350
# 2/2 [==============================] - 0s 118ms/step - loss: 1.9032 - acc: 0.8241 - val_loss: 1.9075 - val_acc: 0.6667
# Epoch 219/350
# 2/2 [==============================] - 0s 146ms/step - loss: 1.9111 - acc: 0.7870 - val_loss: 1.9038 - val_acc: 0.6667
# Epoch 220/350
# 2/2 [==============================] - 0s 114ms/step - loss: 1.8914 - acc: 0.8241 - val_loss: 1.9001 - val_acc: 0.6667
# Epoch 221/350
# 2/2 [==============================] - 0s 106ms/step - loss: 1.8914 - acc: 0.8333 - val_loss: 1.8966 - val_acc: 0.6667
# Epoch 222/350
# 2/2 [==============================] - 0s 137ms/step - loss: 1.8942 - acc: 0.8148 - val_loss: 1.8929 - val_acc: 0.6667
# Epoch 223/350
# 2/2 [==============================] - 0s 119ms/step - loss: 1.8910 - acc: 0.8148 - val_loss: 1.8896 - val_acc: 0.6667
# Epoch 224/350
# 2/2 [==============================] - 0s 135ms/step - loss: 1.9126 - acc: 0.7685 - val_loss: 1.8859 - val_acc: 0.6667
# Epoch 225/350
# 2/2 [==============================] - 0s 158ms/step - loss: 1.8760 - acc: 0.8241 - val_loss: 1.8822 - val_acc: 0.6667
# Epoch 226/350
# 2/2 [==============================] - 0s 139ms/step - loss: 1.8890 - acc: 0.7685 - val_loss: 1.8786 - val_acc: 0.6667
# Epoch 227/350
# 2/2 [==============================] - 0s 146ms/step - loss: 1.8589 - acc: 0.8333 - val_loss: 1.8745 - val_acc: 0.6667
# Epoch 228/350
# 2/2 [==============================] - 0s 110ms/step - loss: 1.8850 - acc: 0.7963 - val_loss: 1.8704 - val_acc: 0.5833
# Epoch 229/350
# 2/2 [==============================] - 0s 104ms/step - loss: 1.8871 - acc: 0.7778 - val_loss: 1.8662 - val_acc: 0.5833
# Epoch 230/350
# 2/2 [==============================] - 0s 107ms/step - loss: 1.8791 - acc: 0.7778 - val_loss: 1.8623 - val_acc: 0.5833
# Epoch 231/350
# 2/2 [==============================] - 0s 134ms/step - loss: 1.8674 - acc: 0.7870 - val_loss: 1.8584 - val_acc: 0.5833
# Epoch 232/350
# 2/2 [==============================] - 0s 108ms/step - loss: 1.8449 - acc: 0.8241 - val_loss: 1.8542 - val_acc: 0.5833
# Epoch 233/350
# 2/2 [==============================] - 0s 140ms/step - loss: 1.8341 - acc: 0.8056 - val_loss: 1.8504 - val_acc: 0.5833
# Epoch 234/350
# 2/2 [==============================] - 0s 108ms/step - loss: 1.8308 - acc: 0.8333 - val_loss: 1.8461 - val_acc: 0.5833
# Epoch 235/350
# 2/2 [==============================] - 0s 146ms/step - loss: 1.8592 - acc: 0.7963 - val_loss: 1.8420 - val_acc: 0.5833
# Epoch 236/350
# 2/2 [==============================] - 0s 114ms/step - loss: 1.8110 - acc: 0.8056 - val_loss: 1.8381 - val_acc: 0.5833
# Epoch 237/350
# 2/2 [==============================] - 0s 156ms/step - loss: 1.8340 - acc: 0.8426 - val_loss: 1.8343 - val_acc: 0.5833
# Epoch 238/350
# 2/2 [==============================] - 0s 111ms/step - loss: 1.8299 - acc: 0.8241 - val_loss: 1.8305 - val_acc: 0.5833
# Epoch 239/350
# 2/2 [==============================] - 0s 117ms/step - loss: 1.8352 - acc: 0.7593 - val_loss: 1.8266 - val_acc: 0.6667
# Epoch 240/350
# 2/2 [==============================] - 0s 136ms/step - loss: 1.8064 - acc: 0.8241 - val_loss: 1.8229 - val_acc: 0.6667
# Epoch 241/350
# 2/2 [==============================] - 0s 134ms/step - loss: 1.8444 - acc: 0.8241 - val_loss: 1.8190 - val_acc: 0.6667
# Epoch 242/350
# 2/2 [==============================] - 0s 122ms/step - loss: 1.8163 - acc: 0.8519 - val_loss: 1.8149 - val_acc: 0.6667
# Epoch 243/350
# 2/2 [==============================] - 0s 111ms/step - loss: 1.8062 - acc: 0.8056 - val_loss: 1.8110 - val_acc: 0.6667
# Epoch 244/350
# 2/2 [==============================] - 0s 121ms/step - loss: 1.8055 - acc: 0.8611 - val_loss: 1.8072 - val_acc: 0.6667
# Epoch 245/350
# 2/2 [==============================] - 0s 170ms/step - loss: 1.7926 - acc: 0.7685 - val_loss: 1.8029 - val_acc: 0.6667
# Epoch 246/350
# 2/2 [==============================] - 0s 113ms/step - loss: 1.7940 - acc: 0.8148 - val_loss: 1.7987 - val_acc: 0.6667
# Epoch 247/350
# 2/2 [==============================] - 0s 176ms/step - loss: 1.7994 - acc: 0.7963 - val_loss: 1.7948 - val_acc: 0.6667
# Epoch 248/350
# 2/2 [==============================] - 0s 126ms/step - loss: 1.8021 - acc: 0.8056 - val_loss: 1.7906 - val_acc: 0.6667
# Epoch 249/350
# 2/2 [==============================] - 0s 205ms/step - loss: 1.7867 - acc: 0.8241 - val_loss: 1.7864 - val_acc: 0.6667
# Epoch 250/350
# 2/2 [==============================] - 0s 193ms/step - loss: 1.8018 - acc: 0.7963 - val_loss: 1.7821 - val_acc: 0.6667
# Epoch 251/350
# 2/2 [==============================] - 0s 203ms/step - loss: 1.7799 - acc: 0.8426 - val_loss: 1.7781 - val_acc: 0.6667
# Epoch 252/350
# 2/2 [==============================] - 0s 190ms/step - loss: 1.7656 - acc: 0.7870 - val_loss: 1.7746 - val_acc: 0.6667
# Epoch 253/350
# 2/2 [==============================] - 0s 200ms/step - loss: 1.7840 - acc: 0.8519 - val_loss: 1.7707 - val_acc: 0.6667
# Epoch 254/350
# 2/2 [==============================] - 0s 196ms/step - loss: 1.7525 - acc: 0.8056 - val_loss: 1.7668 - val_acc: 0.6667
# Epoch 255/350
# 2/2 [==============================] - 0s 192ms/step - loss: 1.7731 - acc: 0.8519 - val_loss: 1.7627 - val_acc: 0.6667
# Epoch 256/350
# 2/2 [==============================] - 0s 200ms/step - loss: 1.7734 - acc: 0.8426 - val_loss: 1.7590 - val_acc: 0.6667
# Epoch 257/350
# 2/2 [==============================] - 0s 193ms/step - loss: 1.7712 - acc: 0.7778 - val_loss: 1.7548 - val_acc: 0.6667
# Epoch 258/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.7325 - acc: 0.8148 - val_loss: 1.7510 - val_acc: 0.6667
# Epoch 259/350
# 2/2 [==============================] - 0s 204ms/step - loss: 1.7445 - acc: 0.8333 - val_loss: 1.7476 - val_acc: 0.6667
# Epoch 260/350
# 2/2 [==============================] - 0s 224ms/step - loss: 1.7329 - acc: 0.8148 - val_loss: 1.7442 - val_acc: 0.6667
# Epoch 261/350
# 2/2 [==============================] - 0s 191ms/step - loss: 1.7638 - acc: 0.7870 - val_loss: 1.7412 - val_acc: 0.6667
# Epoch 262/350
# 2/2 [==============================] - 0s 195ms/step - loss: 1.7299 - acc: 0.7963 - val_loss: 1.7381 - val_acc: 0.6667
# Epoch 263/350
# 2/2 [==============================] - 0s 203ms/step - loss: 1.7518 - acc: 0.8333 - val_loss: 1.7348 - val_acc: 0.6667
# Epoch 264/350
# 2/2 [==============================] - 0s 197ms/step - loss: 1.7083 - acc: 0.8333 - val_loss: 1.7318 - val_acc: 0.6667
# Epoch 265/350
# 2/2 [==============================] - 0s 195ms/step - loss: 1.7084 - acc: 0.7963 - val_loss: 1.7282 - val_acc: 0.6667
# Epoch 266/350
# 2/2 [==============================] - 0s 213ms/step - loss: 1.6897 - acc: 0.8056 - val_loss: 1.7251 - val_acc: 0.6667
# Epoch 267/350
# 2/2 [==============================] - 0s 188ms/step - loss: 1.7033 - acc: 0.8241 - val_loss: 1.7218 - val_acc: 0.6667
# Epoch 268/350
# 2/2 [==============================] - 0s 217ms/step - loss: 1.7164 - acc: 0.8333 - val_loss: 1.7181 - val_acc: 0.6667
# Epoch 269/350
# 2/2 [==============================] - 0s 205ms/step - loss: 1.7231 - acc: 0.7963 - val_loss: 1.7146 - val_acc: 0.6667
# Epoch 270/350
# 2/2 [==============================] - 0s 196ms/step - loss: 1.6991 - acc: 0.8889 - val_loss: 1.7111 - val_acc: 0.6667
# Epoch 271/350
# 2/2 [==============================] - 0s 186ms/step - loss: 1.6913 - acc: 0.8241 - val_loss: 1.7073 - val_acc: 0.6667
# Epoch 272/350
# 2/2 [==============================] - 0s 199ms/step - loss: 1.7213 - acc: 0.8241 - val_loss: 1.7039 - val_acc: 0.6667
# Epoch 273/350
# 2/2 [==============================] - 0s 206ms/step - loss: 1.6957 - acc: 0.8519 - val_loss: 1.7000 - val_acc: 0.6667
# Epoch 274/350
# 2/2 [==============================] - 0s 182ms/step - loss: 1.6720 - acc: 0.8611 - val_loss: 1.6964 - val_acc: 0.6667
# Epoch 275/350
# 2/2 [==============================] - 0s 222ms/step - loss: 1.7053 - acc: 0.7778 - val_loss: 1.6929 - val_acc: 0.6667
# Epoch 276/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.6898 - acc: 0.8148 - val_loss: 1.6896 - val_acc: 0.6667
# Epoch 277/350
# 2/2 [==============================] - 0s 186ms/step - loss: 1.6532 - acc: 0.8241 - val_loss: 1.6860 - val_acc: 0.6667
# Epoch 278/350
# 2/2 [==============================] - 0s 217ms/step - loss: 1.6742 - acc: 0.8333 - val_loss: 1.6823 - val_acc: 0.6667
# Epoch 279/350
# 2/2 [==============================] - 0s 157ms/step - loss: 1.6276 - acc: 0.8796 - val_loss: 1.6790 - val_acc: 0.6667
# Epoch 280/350
# 2/2 [==============================] - 0s 196ms/step - loss: 1.6450 - acc: 0.8519 - val_loss: 1.6759 - val_acc: 0.6667
# Epoch 281/350
# 2/2 [==============================] - 0s 197ms/step - loss: 1.6455 - acc: 0.8056 - val_loss: 1.6732 - val_acc: 0.6667
# Epoch 282/350
# 2/2 [==============================] - 0s 214ms/step - loss: 1.6818 - acc: 0.7963 - val_loss: 1.6701 - val_acc: 0.6667
# Epoch 283/350
# 2/2 [==============================] - 0s 191ms/step - loss: 1.6424 - acc: 0.8056 - val_loss: 1.6673 - val_acc: 0.6667
# Epoch 284/350
# 2/2 [==============================] - 0s 203ms/step - loss: 1.6321 - acc: 0.8148 - val_loss: 1.6644 - val_acc: 0.6667
# Epoch 285/350
# 2/2 [==============================] - 0s 192ms/step - loss: 1.6426 - acc: 0.8426 - val_loss: 1.6614 - val_acc: 0.7500
# Epoch 286/350
# 2/2 [==============================] - 0s 213ms/step - loss: 1.6340 - acc: 0.8148 - val_loss: 1.6585 - val_acc: 0.7500
# Epoch 287/350
# 2/2 [==============================] - 0s 214ms/step - loss: 1.6420 - acc: 0.8241 - val_loss: 1.6555 - val_acc: 0.7500
# Epoch 288/350
# 2/2 [==============================] - 0s 205ms/step - loss: 1.6235 - acc: 0.8333 - val_loss: 1.6528 - val_acc: 0.7500
# Epoch 289/350
# 2/2 [==============================] - 0s 215ms/step - loss: 1.6139 - acc: 0.8333 - val_loss: 1.6500 - val_acc: 0.7500
# Epoch 290/350
# 2/2 [==============================] - 0s 161ms/step - loss: 1.6347 - acc: 0.8056 - val_loss: 1.6470 - val_acc: 0.7500
# Epoch 291/350
# 2/2 [==============================] - 0s 172ms/step - loss: 1.6006 - acc: 0.8426 - val_loss: 1.6439 - val_acc: 0.7500
# Epoch 292/350
# 2/2 [==============================] - 0s 173ms/step - loss: 1.6024 - acc: 0.8333 - val_loss: 1.6410 - val_acc: 0.7500
# Epoch 293/350
# 2/2 [==============================] - 0s 147ms/step - loss: 1.6220 - acc: 0.8148 - val_loss: 1.6381 - val_acc: 0.7500
# Epoch 294/350
# 2/2 [==============================] - 0s 170ms/step - loss: 1.6121 - acc: 0.8426 - val_loss: 1.6352 - val_acc: 0.7500
# Epoch 295/350
# 2/2 [==============================] - 0s 152ms/step - loss: 1.6399 - acc: 0.8148 - val_loss: 1.6323 - val_acc: 0.7500
# Epoch 296/350
# 2/2 [==============================] - 0s 185ms/step - loss: 1.6002 - acc: 0.8519 - val_loss: 1.6289 - val_acc: 0.7500
# Epoch 297/350
# 2/2 [==============================] - 0s 164ms/step - loss: 1.5662 - acc: 0.8796 - val_loss: 1.6258 - val_acc: 0.7500
# Epoch 298/350
# 2/2 [==============================] - 0s 156ms/step - loss: 1.5914 - acc: 0.8148 - val_loss: 1.6227 - val_acc: 0.7500
# Epoch 299/350
# 2/2 [==============================] - 0s 183ms/step - loss: 1.5692 - acc: 0.8704 - val_loss: 1.6198 - val_acc: 0.7500
# Epoch 300/350
# 2/2 [==============================] - 0s 164ms/step - loss: 1.6047 - acc: 0.8611 - val_loss: 1.6170 - val_acc: 0.7500
# Epoch 301/350
# 2/2 [==============================] - 0s 149ms/step - loss: 1.5928 - acc: 0.8426 - val_loss: 1.6141 - val_acc: 0.7500
# Epoch 302/350
# 2/2 [==============================] - 0s 161ms/step - loss: 1.5926 - acc: 0.8611 - val_loss: 1.6111 - val_acc: 0.7500
# Epoch 303/350
# 2/2 [==============================] - 0s 198ms/step - loss: 1.5863 - acc: 0.8056 - val_loss: 1.6084 - val_acc: 0.7500
# Epoch 304/350
# 2/2 [==============================] - 0s 166ms/step - loss: 1.5874 - acc: 0.8704 - val_loss: 1.6057 - val_acc: 0.7500
# Epoch 305/350
# 2/2 [==============================] - 0s 141ms/step - loss: 1.5517 - acc: 0.8333 - val_loss: 1.6029 - val_acc: 0.7500
# Epoch 306/350
# 2/2 [==============================] - 0s 136ms/step - loss: 1.5596 - acc: 0.7963 - val_loss: 1.6001 - val_acc: 0.7500
# Epoch 307/350
# 2/2 [==============================] - 0s 142ms/step - loss: 1.5724 - acc: 0.8148 - val_loss: 1.5971 - val_acc: 0.7500
# Epoch 308/350
# 2/2 [==============================] - 0s 139ms/step - loss: 1.5477 - acc: 0.8148 - val_loss: 1.5942 - val_acc: 0.7500
# Epoch 309/350
# 2/2 [==============================] - 0s 136ms/step - loss: 1.5451 - acc: 0.7407 - val_loss: 1.5913 - val_acc: 0.7500
# Epoch 310/350
# 2/2 [==============================] - 0s 134ms/step - loss: 1.5429 - acc: 0.8148 - val_loss: 1.5885 - val_acc: 0.7500
# Epoch 311/350
# 2/2 [==============================] - 0s 199ms/step - loss: 1.5731 - acc: 0.8241 - val_loss: 1.5854 - val_acc: 0.7500
# Epoch 312/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.5620 - acc: 0.8241 - val_loss: 1.5820 - val_acc: 0.7500
# Epoch 313/350
# 2/2 [==============================] - 0s 219ms/step - loss: 1.5161 - acc: 0.8704 - val_loss: 1.5791 - val_acc: 0.7500
# Epoch 314/350
# 2/2 [==============================] - 0s 183ms/step - loss: 1.5278 - acc: 0.8611 - val_loss: 1.5761 - val_acc: 0.7500
# Epoch 315/350
# 2/2 [==============================] - 0s 197ms/step - loss: 1.5481 - acc: 0.8611 - val_loss: 1.5731 - val_acc: 0.7500
# Epoch 316/350
# 2/2 [==============================] - 0s 183ms/step - loss: 1.5153 - acc: 0.8611 - val_loss: 1.5702 - val_acc: 0.7500
# Epoch 317/350
# 2/2 [==============================] - 0s 209ms/step - loss: 1.5393 - acc: 0.8519 - val_loss: 1.5670 - val_acc: 0.7500
# Epoch 318/350
# 2/2 [==============================] - 0s 220ms/step - loss: 1.5344 - acc: 0.8519 - val_loss: 1.5638 - val_acc: 0.7500
# Epoch 319/350
# 2/2 [==============================] - 0s 208ms/step - loss: 1.5231 - acc: 0.8519 - val_loss: 1.5613 - val_acc: 0.7500
# Epoch 320/350
# 2/2 [==============================] - 0s 217ms/step - loss: 1.5166 - acc: 0.8241 - val_loss: 1.5586 - val_acc: 0.7500
# Epoch 321/350
# 2/2 [==============================] - 0s 195ms/step - loss: 1.5330 - acc: 0.8241 - val_loss: 1.5557 - val_acc: 0.7500
# Epoch 322/350
# 2/2 [==============================] - 0s 199ms/step - loss: 1.4698 - acc: 0.8611 - val_loss: 1.5529 - val_acc: 0.7500
# Epoch 323/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.5178 - acc: 0.8704 - val_loss: 1.5504 - val_acc: 0.7500
# Epoch 324/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.4990 - acc: 0.8426 - val_loss: 1.5479 - val_acc: 0.7500
# Epoch 325/350
# 2/2 [==============================] - 0s 220ms/step - loss: 1.4993 - acc: 0.8611 - val_loss: 1.5455 - val_acc: 0.7500
# Epoch 326/350
# 2/2 [==============================] - 0s 211ms/step - loss: 1.4726 - acc: 0.8981 - val_loss: 1.5429 - val_acc: 0.7500
# Epoch 327/350
# 2/2 [==============================] - 0s 209ms/step - loss: 1.4954 - acc: 0.7870 - val_loss: 1.5405 - val_acc: 0.7500
# Epoch 328/350
# 2/2 [==============================] - 0s 170ms/step - loss: 1.5073 - acc: 0.8333 - val_loss: 1.5379 - val_acc: 0.7500
# Epoch 329/350
# 2/2 [==============================] - 0s 213ms/step - loss: 1.4926 - acc: 0.8611 - val_loss: 1.5354 - val_acc: 0.7500
# Epoch 330/350
# 2/2 [==============================] - 0s 185ms/step - loss: 1.4841 - acc: 0.8519 - val_loss: 1.5326 - val_acc: 0.7500
# Epoch 331/350
# 2/2 [==============================] - 0s 187ms/step - loss: 1.4731 - acc: 0.8704 - val_loss: 1.5303 - val_acc: 0.7500
# Epoch 332/350
# 2/2 [==============================] - 0s 211ms/step - loss: 1.5363 - acc: 0.8426 - val_loss: 1.5276 - val_acc: 0.7500
# Epoch 333/350
# 2/2 [==============================] - 0s 182ms/step - loss: 1.4456 - acc: 0.8704 - val_loss: 1.5253 - val_acc: 0.7500
# Epoch 334/350
# 2/2 [==============================] - 0s 216ms/step - loss: 1.4701 - acc: 0.8426 - val_loss: 1.5226 - val_acc: 0.7500
# Epoch 335/350
# 2/2 [==============================] - 0s 208ms/step - loss: 1.4605 - acc: 0.7963 - val_loss: 1.5201 - val_acc: 0.7500
# Epoch 336/350
# 2/2 [==============================] - 0s 200ms/step - loss: 1.4767 - acc: 0.8796 - val_loss: 1.5175 - val_acc: 0.7500
# Epoch 337/350
# 2/2 [==============================] - 0s 215ms/step - loss: 1.4729 - acc: 0.8148 - val_loss: 1.5144 - val_acc: 0.7500
# Epoch 338/350
# 2/2 [==============================] - 0s 192ms/step - loss: 1.4797 - acc: 0.8611 - val_loss: 1.5115 - val_acc: 0.7500
# Epoch 339/350
# 2/2 [==============================] - 0s 230ms/step - loss: 1.4485 - acc: 0.8426 - val_loss: 1.5087 - val_acc: 0.7500
# Epoch 340/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.4458 - acc: 0.8704 - val_loss: 1.5060 - val_acc: 0.7500
# Epoch 341/350
# 2/2 [==============================] - 0s 209ms/step - loss: 1.4496 - acc: 0.8056 - val_loss: 1.5037 - val_acc: 0.7500
# Epoch 342/350
# 2/2 [==============================] - 0s 199ms/step - loss: 1.4680 - acc: 0.8148 - val_loss: 1.5014 - val_acc: 0.7500
# Epoch 343/350
# 2/2 [==============================] - 0s 222ms/step - loss: 1.4694 - acc: 0.8426 - val_loss: 1.4993 - val_acc: 0.7500
# Epoch 344/350
# 2/2 [==============================] - 0s 214ms/step - loss: 1.4395 - acc: 0.8519 - val_loss: 1.4972 - val_acc: 0.7500
# Epoch 345/350
# 2/2 [==============================] - 0s 201ms/step - loss: 1.4525 - acc: 0.8241 - val_loss: 1.4950 - val_acc: 0.7500
# Epoch 346/350
# 2/2 [==============================] - 0s 199ms/step - loss: 1.4734 - acc: 0.8426 - val_loss: 1.4928 - val_acc: 0.7500
# Epoch 347/350
# 2/2 [==============================] - 0s 197ms/step - loss: 1.4356 - acc: 0.8241 - val_loss: 1.4908 - val_acc: 0.7500
# Epoch 348/350
# 2/2 [==============================] - 0s 220ms/step - loss: 1.4439 - acc: 0.8333 - val_loss: 1.4887 - val_acc: 0.7500
# Epoch 349/350
# 2/2 [==============================] - 0s 206ms/step - loss: 1.4713 - acc: 0.8796 - val_loss: 1.4860 - val_acc: 0.7500
# Epoch 350/350
# 2/2 [==============================] - 0s 213ms/step - loss: 1.4305 - acc: 0.8796 - val_loss: 1.4832 - val_acc: 0.7500

# %%
xticks = list(range(epochs))
# plot the avg across folds
ax = sns.lineplot(x=xticks, y=history.history['acc'], label='training_acc')
ax = sns.lineplot(x=xticks, y=history.history['val_acc'], label='testing_acc', ax=ax)
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('EEGNet')
# Out:
# Text(0.5, 1.0, 'EEGNet')
